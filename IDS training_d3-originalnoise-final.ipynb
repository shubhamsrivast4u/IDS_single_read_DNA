# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import random
from torch.utils.data import Dataset, DataLoader
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"  # Select the GPU index
import nltk
from torch.optim.lr_scheduler import _LRScheduler
import time
import math
import matplotlib.pyplot as plt
import spacy
from scipy.io import savemat
import dill as pickle
import thop

# %%
# Dictionary
dicno=3
dictionaries =[[],
               
               [],
               
               [],
               
               ['ACGTAGCAGA', 'ACTACAGACG', 'AGACGATGCA', 'AGCGACTATC', 'ATAGCTCGTG', 'CACGAGCTAT','CGTCTGTAGT',
                'CTATCAGCGA', 'GATAGTCGCT', 'GCAGACATCA', 'GTGCTCGATA', 'TATCGAGCAC', 'TCGCTGATAG', 'TCTGCTACGT',
                'TGATGTCTGC', 'TGCATCGTCT'],
               
               ['ATCGATCGATCGAT','TACGTAGCTAGCTA', 'TAGCTACGTAGCTA', 'ATGCATGCATCGAT', 'ATGCTACGATGCTA', 
                'TAGCATGCTACGAT', 'TACGATCGTACGAT', 'ATCGTAGCATGCTA', 'TACGATGCTAGCAT', 'ATCGTACGATCGTA', 
                'ATGCTAGCATCGTA', 'TAGCATCGTAGCAT', 'TAGCTAGCTACGTA', 'ATGCATCGATGCAT', 'ATCGATGCATGCAT', 
                'TACGTACGTACGTA'],
              
               []
              
               ]
dicts=dictionaries[dicno]
print(dicts)
# Out:
# ['ACGTAGCAGA', 'ACTACAGACG', 'AGACGATGCA', 'AGCGACTATC', 'ATAGCTCGTG', 'CACGAGCTAT', 'CGTCTGTAGT', 'CTATCAGCGA', 'GATAGTCGCT', 'GCAGACATCA', 'GTGCTCGATA', 'TATCGAGCAC', 'TCGCTGATAG', 'TCTGCTACGT', 'TGATGTCTGC', 'TGCATCGTCT']

# %%
batch_size=2000
device = 'cuda' if torch.cuda.is_available() else 'cpu'
lr=0.001
num_epochs=500
final_num_epochs=200
patience=400
train_num_samples=30000
test_num_samples=10000
final_train_num_samples=500000
final_test_num_samples=10000
num_errors=4
K=len(dicts[0])
hidden_size=32

# %%
path_directory=f"finalmodels/BiLSTM/Dictionary_{dicno}/batch_size_{batch_size}/num_errors_{num_errors}/initial_lr_{lr}/epochs{final_num_epochs}_p{patience}_tr{final_train_num_samples}ts{final_test_num_samples}K{K}hs{hidden_size}/"
path_directory
# Out:
# 'finalmodels/BiLSTM/Dictionary_3/batch_size_2000/num_errors_4/initial_lr_0.001/epochs200_p400_tr500000ts10000K10hs32/'

# %%
# Check if "models" folder exists, create it if it doesn't
if not os.path.exists(path_directory):
    os.makedirs(path_directory)

# %%
class BiLSTMDeletionModel(nn.Module):

    def __init__(self, hidden_size, dropout):
        super().__init__()
        
        self.lstm1 = nn.LSTM(
            input_size=5, 
            hidden_size=hidden_size,
            num_layers=2,
            batch_first=True,
            bidirectional=True,
            dropout=dropout
        )
        self.fc = nn.Linear(2*hidden_size, 4)
        self.softmax = nn.Softmax(dim=2)
    def forward(self, x):

        # BiLSTM 1
        out, _ = self.lstm1(x)
        out = self.softmax(self.fc(out))
        return out

# %%
deletion_model = BiLSTMDeletionModel(hidden_size,0.1)

# %%
deletion_path_directory=f"deletionmodels/BiLSTM/Dictionary_{dicno}/batch_size_{batch_size}/num_errors_{num_errors}/initial_lr_{lr}/epochs{num_epochs}_p{patience}_tr{train_num_samples}ts{test_num_samples}K{K}hs{hidden_size}/"
deletion_path_directory
# Out:
# 'deletionmodels/BiLSTM/Dictionary_3/batch_size_2000/num_errors_4/initial_lr_0.001/epochs500_p400_tr30000ts10000K10hs32/'

# %%
deletion_model.load_state_dict(torch.load(deletion_path_directory+"model.pth"), strict=False)
# Out:
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['total_ops', 'total_params'])

# %%
class BiLSTMsubstitutionModel(nn.Module):

    def __init__(self, hidden_size, dropout):
        super().__init__()
        
        self.lstm1 = nn.LSTM(
            input_size=4, 
            hidden_size=hidden_size,
            num_layers=2,
            batch_first=True,
            bidirectional=True,
            dropout=dropout
        )
        self.fc = nn.Linear(2*hidden_size, 4)
        self.softmax = nn.Softmax(dim=2)
    def forward(self, x):

        # BiLSTM 1
        out, _ = self.lstm1(x)
        out = self.softmax(self.fc(out))
        return out

# %%
substitution_model = BiLSTMsubstitutionModel(hidden_size,0.1)

# %%
substitution_path_directory=f"substitutionmodels/BiLSTM/Dictionary_{dicno}/batch_size_{batch_size}/num_errors_{num_errors}/initial_lr_{lr}/epochs{num_epochs}_p{patience}_tr{train_num_samples}ts{test_num_samples}K{K}hs{hidden_size}/"
substitution_path_directory
# Out:
# 'substitutionmodels/BiLSTM/Dictionary_3/batch_size_2000/num_errors_4/initial_lr_0.001/epochs500_p400_tr30000ts10000K10hs32/'

# %%
substitution_model.load_state_dict(torch.load(substitution_path_directory+"model.pth"), strict=False)
# Out:
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['total_ops', 'total_params'])

# %%
class BiLSTMinsertionModel(nn.Module):

    def __init__(self, hidden_size, dropout):
        super().__init__()
        
        self.lstm1 = nn.LSTM(
            input_size=5, 
            hidden_size=hidden_size,
            num_layers=2,
            batch_first=True,
            bidirectional=True,
            dropout=dropout
        )
        self.fc = nn.Linear(2*hidden_size, 5)
        self.softmax = nn.Softmax(dim=2)
    def forward(self, x):

        # BiLSTM 1
        out, _ = self.lstm1(x)
        out = self.softmax(self.fc(out))
        return out

# %%
insertion_model = BiLSTMinsertionModel(hidden_size,0.1)

# %%
insertion_path_directory=f"insertionmodels/BiLSTM/Dictionary_{dicno}/batch_size_{batch_size}/num_errors_{num_errors}/initial_lr_{lr}/epochs{num_epochs}_p{patience}_tr{train_num_samples}ts{test_num_samples}K{K}hs{hidden_size}/"
insertion_path_directory
# Out:
# 'insertionmodels/BiLSTM/Dictionary_3/batch_size_2000/num_errors_4/initial_lr_0.001/epochs500_p400_tr30000ts10000K10hs32/'

# %%
insertion_model.load_state_dict(torch.load(insertion_path_directory+"model.pth"), strict=False)
# Out:
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['total_ops', 'total_params'])

# %%
insertion_model.to(device)
substitution_model.to(device)
deletion_model.to(device)
# Out:
# BiLSTMDeletionModel(
#   (lstm1): LSTM(5, 32, num_layers=2, batch_first=True, dropout=0.1, bidirectional=True)
#   (fc): Linear(in_features=64, out_features=4, bias=True)
#   (softmax): Softmax(dim=2)
# )

# %%
class BiLSTMcombinerModel(nn.Module):

    def __init__(self, hidden_size, dropout):
        super().__init__()
        self.lstm1 = nn.LSTM(
            input_size=4, 
            hidden_size=5*hidden_size,
            num_layers=2,
            batch_first=True,
            bidirectional=True,
            dropout=dropout
        )
        self.fc = nn.Linear(10*hidden_size, 5)
        self.softmax = nn.Softmax(dim=2)
    def forward(self, x):
        # BiLSTM 1
        out, _ = self.lstm1(x)
        out = self.softmax(self.fc(out))
        return out

# %%
combiner_model=BiLSTMcombinerModel(hidden_size,0.1)

# %%
class ParallelEnsemble(nn.Module):
    def __init__(self, insertion_model, deletion_model, substitution_model, combiner_model):
        super().__init__()
        self.insert_model = insertion_model 
        self.delete_model = deletion_model
        self.subst_model = substitution_model
        self.combiner_model = combiner_model
        
        # Freeze insertion, deletion, substitution models
        for param in self.insert_model.parameters():
            param.requires_grad = False

        for param in self.delete_model.parameters():
            param.requires_grad = False

        for param in self.subst_model.parameters():
            param.requires_grad = False

        # Ensure combiner model is trainable
        for param in self.combiner_model.parameters():
            param.requires_grad = True

    def forward(self, x):
        # Get predictions in parallel 
        insert_in = one_hot_encode(x.to(device), 5)
        insert_out = self.insert_model(insert_in)  
        delete_in = one_hot_encode(x[:,:K].to(device), 5)
        delete_out = self.delete_model(delete_in)
        subst_in = one_hot_encode(x[:,:K].to(device), 5)
        subst_out = self.subst_model(subst_in[:,:,:4])
        # Combine parallel outputs  
        combined_out = torch.cat([insert_out[:,:K,:4], delete_out[:,:K,:4], subst_out[:,:K,:4]], dim=1)
        # Final correction  
        y = self.combiner_model(combined_out)
        return y

ensemble = ParallelEnsemble(insertion_model, deletion_model, substitution_model, combiner_model).to(device)

# %%
def one_hot_encode(sequences, n_unique):

    # Get size of batch and max sequence length
    batch_size,seq_len=sequences.shape
    #len(sequences)
    #seq_len=len(sequences[0])
    
    # Initialize encoded tensor
    oneencoding = torch.zeros(batch_size, seq_len, n_unique, device = device)
    # Set 1 at index of each character
    for i in range(batch_size):
        for j in range(seq_len):
            index = sequences[i][j]
            oneencoding[i, j, index] = 1          
    return oneencoding

# %%
def one_hot_decode(encoded_seq):
    """Converts a batch of one-hot encoded sequences to indices"""
    
    # Dimensions will be (batch_size, seq_len, num_classes)
    batch_size, seq_len, num_classes = encoded_seq.shape
    
    # Flatten to treat as a list of one-hot vectors
    encoded_seq = encoded_seq.reshape(-1, num_classes)
    
    # Argmax over classes to get class index
    indices = encoded_seq.argmax(dim=1).to(device)
    
    # Reshape back to original dimensions
    indices = indices.reshape(batch_size, seq_len)
    
    return indices

# %%
class LanguageDataset1(Dataset):

    def __init__(self, dictionary, num_samples, num_errors):
        self.dictionary = dictionary
        self.num_samples = num_samples 
        self.num_errors = num_errors

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        source_idx = idx % len(self.dictionary)
        sequence = self.dictionary[source_idx]
        choice = torch.rand(1).item()
        if self.num_errors > 0:
            if choice >= 0 and choice< 0.10646:
                sequence = self.introduce_substitution_errors(sequence, self.num_errors)
                for _ in range(self.num_errors):
                    sequence.append('N')  
                sequence=''.join(sequence)
                #sequence= torch.cat([sequence, 'NNNN'], dim=1)
            elif choice >=0.10646 and choice < 0.14218:
                sequence = self.introduce_deletion_errors(sequence, self.num_errors)
                for _ in range(self.num_errors):
                    sequence.append('N') 
                sequence=''.join(sequence)
                #sequence= torch.cat([sequence, 'NNNN'], dim=1)
            elif choice >=0.14218 and choice < 0.15163:
                sequence = self.introduce_insertion_errors(sequence, self.num_errors)
                sequence=''.join(sequence)
            elif choice >=0.15163 and choice < 0.156:
                ne1 = self.num_errors//2
                ne2 = self.num_errors- ne1
                sequence = self.introduce_substitution_errors(sequence, ne1)
                sequence=''.join(sequence)
                sequence = self.introduce_deletion_errors(sequence, ne2)
                for _ in range(self.num_errors):
                    sequence.append('N') 
                sequence=''.join(sequence)
                #sequence= torch.cat([sequence, 'NNNN'], dim=1)
            elif choice >=0.156 and choice < 0.15701:
                ne1 = self.num_errors//2
                ne2 = self.num_errors- ne1
                sequence = self.introduce_substitution_errors(sequence, ne1)
                for _ in range(ne1):
                    sequence.append('N') 
                sequence=''.join(sequence)
                sequence = self.introduce_insertion_errors(sequence, ne2)
                sequence=''.join(sequence)
                
                
            elif choice >=0.15701 and choice < 0.1574:
                ne1 = self.num_errors//2
                ne2 = self.num_errors- ne1
                sequence = self.introduce_deletion_errors(sequence, ne1)
                for _ in range(ne1):
                    sequence.append('N') 
                sequence=''.join(sequence)
                sequence = self.introduce_insertion_errors(sequence, ne2)
                sequence=''.join(sequence)
                
            elif choice >=0.1574 and choice < 0.15747:
                ne1 = self.num_errors//3
                ne2 = self.num_errors//3
                ne3 = self.num_errors- ne1-ne2
                sequence = self.introduce_substitution_errors(sequence, ne1)
                for _ in range(ne1):
                    sequence.append('N')
                sequence=''.join(sequence)
                sequence = self.introduce_deletion_errors(sequence, ne2)
                for _ in range(ne2):
                    sequence.append('N')
                sequence=''.join(sequence)
                sequence = self.introduce_insertion_errors(sequence, ne3)
                sequence=''.join(sequence)
                  
            else:
                sequence = list(sequence)
                for _ in range(self.num_errors):
                    sequence.append('N') 
                sequence=''.join(sequence) 
            
        x = torch.tensor([self.char_to_idx(c) for c in sequence], dtype=torch.long)
        y = torch.tensor([self.char_to_idx(c) for c in self.dictionary[source_idx]], dtype=torch.long)
        return x.to(device), y.to(device)

    def introduce_deletion_errors(self, sequence, num_errors):
        ne = random.randint(1, num_errors)
        sequence = list(sequence)
        
        for _ in range(ne):
            i = random.randint(0, len(sequence)-1)
            del sequence[i]
            sequence.append('N') 
        
        return sequence
    
    def introduce_substitution_errors(self, sequence, num_errors):
        ne = random.randint(1, num_errors)
        sequence = list(sequence)
        for _ in range(ne):
            i = random.randint(0, len(sequence)-1)
            if sequence[i] == 'A':
                sequence[i] = random.choice(['T', 'G', 'C'])
            elif sequence[i] == 'T':
                sequence[i] = random.choice(['A', 'G', 'C'])
            elif sequence[i] == 'G':
                sequence[i] = random.choice(['A', 'T', 'C'])
            elif sequence[i] == 'C':
                sequence[i] = random.choice(['A', 'T', 'G'])
        
        return sequence
    
    def introduce_insertion_errors(self, sequence, num_errors):
        ne = random.randint(1, num_errors)
        sequence = list(sequence)
        for _ in range(num_errors-ne):
            sequence.append('N')
        for _ in range(ne):
            i = random.randint(0, len(sequence))
            random_char = random.choice(['A','C','T','G']) 
            sequence.insert(i, random_char)
        return sequence

    def char_to_idx(self, char):
        return {'A': 0, 'C': 1, 'T': 2, 'G': 3, 'N': 4}[char]

# %%
train_data = LanguageDataset1(dicts, num_samples=final_train_num_samples, num_errors=num_errors)
test_data = LanguageDataset1(dicts, num_samples=final_test_num_samples, num_errors=num_errors)

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size)

# %%
criterion= nn.MSELoss().to(device)
optimizer = torch.optim.Adam(ensemble.parameters(), lr=lr, betas=(0.9, 0.98), eps=1e-9)

# %%
class WarmUpCosineAnnealingLR(_LRScheduler):
    def __init__(self, optimizer, T_max, T_warmup, eta_min=0, last_epoch=-1):
        self.T_max = T_max
        self.T_warmup = T_warmup
        self.eta_min = eta_min
        super(WarmUpCosineAnnealingLR, self).__init__(optimizer, last_epoch)

    def get_lr(self):
        if self.last_epoch < self.T_warmup:
            return [base_lr * self.last_epoch / self.T_warmup for base_lr in self.base_lrs]
        else:
            k = 1 + math.cos(math.pi * (self.last_epoch - self.T_warmup) / (self.T_max - self.T_warmup))
            return [self.eta_min + (base_lr - self.eta_min) * k / 2 for base_lr in self.base_lrs]

# %%
scheduler = WarmUpCosineAnnealingLR(optimizer=optimizer,
                                            T_max=final_num_epochs * len(train_loader),
                                            T_warmup=50 * len(train_loader),
                                            eta_min=1e-6)

# %%
start_time = time.time()
num_train_batches=len(train_loader)
num_test_batches=len(test_loader)
train_losses = []
val_losses = []
patience_counter = 0
best_val_loss = float('inf')

for i in range(final_num_epochs):
    loss1 = 0
    epoch_time = time.time()
    ensemble.train()
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):  
        optimizer.zero_grad()
        # Apply the model
        #xt=one_hot_encode(X_train.to(device), 5)
        y_pred=ensemble(X_train)
        #print(y_pred.shape)
        y_train = torch.cat([y_train, 4*torch.ones(batch_size, 2*K, dtype=torch.int).to(device)], dim=1)
        yt=one_hot_encode(y_train, 5).to(device)
        loss = criterion(y_pred, yt) 
        # Update parameters
        loss.backward()
        optimizer.step()
        scheduler.step()
        loss1=loss1+loss
        #if (b+1)%50==1:
        #    print(f'epoch: {i+1}/{num_epochs} batch:{b+1}/{num_train_batches} loss: {loss.item():10.8f}')      
    train_loss=loss1/num_train_batches  
    train_losses.append(train_loss.item())
    # Run the testing batches
    ensemble.eval()
    with torch.no_grad():
        loss1=0
        for b, (X_test, y_test) in enumerate(test_loader):
            
            # Apply the model
            #xt=one_hot_encode(X_test.to(device), 5)
            y_pred=ensemble(X_test)
            y_test = torch.cat([y_test, 4*torch.ones(batch_size, 2*K, dtype=torch.int).to(device)], dim=1)
            yt=one_hot_encode(y_test, 5).to(device)
            loss = criterion(y_pred, yt) 
            loss1=loss1+loss         
        val_loss=loss1/num_test_batches  
        val_losses.append(val_loss.item())
    
    print(f'epoch:{i+1}/{final_num_epochs} average TL:{train_loss.item():10.8f} average VL:{val_loss.item():10.8f} epoch time:{time.time() - epoch_time:.0f} seconds, lr:{optimizer.param_groups[0]["lr"]:.2e}')               
     # Early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(ensemble.state_dict(), path_directory+"model.pth")
        
print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:1/200 average TL:0.15653627 average VL:0.14421175 epoch time:1149 seconds, lr:2.00e-05
# epoch:2/200 average TL:0.09060575 average VL:0.06139482 epoch time:1149 seconds, lr:4.00e-05
# epoch:3/200 average TL:0.05297422 average VL:0.04921431 epoch time:1142 seconds, lr:6.00e-05
# epoch:4/200 average TL:0.04531841 average VL:0.03738123 epoch time:1152 seconds, lr:8.00e-05
# epoch:5/200 average TL:0.01714366 average VL:0.00468785 epoch time:1160 seconds, lr:1.00e-04
# epoch:6/200 average TL:0.00461143 average VL:0.00405509 epoch time:1151 seconds, lr:1.20e-04
# epoch:7/200 average TL:0.00402178 average VL:0.00339293 epoch time:1166 seconds, lr:1.40e-04
# epoch:8/200 average TL:0.00306619 average VL:0.00240591 epoch time:1181 seconds, lr:1.60e-04
# epoch:9/200 average TL:0.00235563 average VL:0.00195763 epoch time:1148 seconds, lr:1.80e-04
# epoch:10/200 average TL:0.00184967 average VL:0.00156175 epoch time:1166 seconds, lr:2.00e-04
# epoch:11/200 average TL:0.00155873 average VL:0.00136720 epoch time:1153 seconds, lr:2.20e-04
# epoch:12/200 average TL:0.00138387 average VL:0.00130652 epoch time:1147 seconds, lr:2.40e-04
# epoch:13/200 average TL:0.00128226 average VL:0.00104698 epoch time:1146 seconds, lr:2.60e-04
# epoch:14/200 average TL:0.00122156 average VL:0.00112348 epoch time:1152 seconds, lr:2.80e-04
# epoch:15/200 average TL:0.00114722 average VL:0.00115763 epoch time:1164 seconds, lr:3.00e-04
# epoch:16/200 average TL:0.00115870 average VL:0.00116834 epoch time:1183 seconds, lr:3.20e-04
# epoch:17/200 average TL:0.00112178 average VL:0.00098278 epoch time:1146 seconds, lr:3.40e-04
# epoch:18/200 average TL:0.00106833 average VL:0.00114253 epoch time:1180 seconds, lr:3.60e-04
# epoch:19/200 average TL:0.00106497 average VL:0.00106618 epoch time:1166 seconds, lr:3.80e-04
# epoch:20/200 average TL:0.00102228 average VL:0.00089952 epoch time:1142 seconds, lr:4.00e-04
# epoch:21/200 average TL:0.00104528 average VL:0.00171588 epoch time:1163 seconds, lr:4.20e-04
# epoch:22/200 average TL:0.00102904 average VL:0.00101093 epoch time:1164 seconds, lr:4.40e-04
# epoch:23/200 average TL:0.00098799 average VL:0.00086004 epoch time:1153 seconds, lr:4.60e-04
# epoch:24/200 average TL:0.00096248 average VL:0.00092303 epoch time:1149 seconds, lr:4.80e-04
# epoch:25/200 average TL:0.00091949 average VL:0.00085752 epoch time:1147 seconds, lr:5.00e-04
# epoch:26/200 average TL:0.00091311 average VL:0.00094802 epoch time:1144 seconds, lr:5.20e-04
# epoch:27/200 average TL:0.00089965 average VL:0.00085354 epoch time:1149 seconds, lr:5.40e-04
# epoch:28/200 average TL:0.00088265 average VL:0.00097023 epoch time:1155 seconds, lr:5.60e-04
# epoch:29/200 average TL:0.00092612 average VL:0.00087486 epoch time:1147 seconds, lr:5.80e-04
# epoch:30/200 average TL:0.00084977 average VL:0.00085301 epoch time:1153 seconds, lr:6.00e-04
# epoch:31/200 average TL:0.00084894 average VL:0.00086985 epoch time:1149 seconds, lr:6.20e-04
# epoch:32/200 average TL:0.00082889 average VL:0.00085284 epoch time:1163 seconds, lr:6.40e-04
# epoch:33/200 average TL:0.00084853 average VL:0.00065058 epoch time:1154 seconds, lr:6.60e-04
# epoch:34/200 average TL:0.00082611 average VL:0.00085642 epoch time:1144 seconds, lr:6.80e-04
# epoch:35/200 average TL:0.00081595 average VL:0.00089433 epoch time:1145 seconds, lr:7.00e-04
# epoch:36/200 average TL:0.00075654 average VL:0.00062056 epoch time:1150 seconds, lr:7.20e-04
# epoch:37/200 average TL:0.00080928 average VL:0.00086350 epoch time:1156 seconds, lr:7.40e-04
# epoch:38/200 average TL:0.00077531 average VL:0.00055339 epoch time:1149 seconds, lr:7.60e-04
# epoch:39/200 average TL:0.00076920 average VL:0.00072311 epoch time:1148 seconds, lr:7.80e-04
# epoch:40/200 average TL:0.00075058 average VL:0.00080841 epoch time:1150 seconds, lr:8.00e-04
# epoch:41/200 average TL:0.00072967 average VL:0.00080992 epoch time:1161 seconds, lr:8.20e-04
# epoch:42/200 average TL:0.00071003 average VL:0.00070258 epoch time:1149 seconds, lr:8.40e-04
# epoch:43/200 average TL:0.00069030 average VL:0.00068959 epoch time:1144 seconds, lr:8.60e-04
# epoch:44/200 average TL:0.00072439 average VL:0.00056377 epoch time:1147 seconds, lr:8.80e-04
# epoch:45/200 average TL:0.00068113 average VL:0.00068208 epoch time:1159 seconds, lr:9.00e-04
# epoch:46/200 average TL:0.00068686 average VL:0.00063341 epoch time:1148 seconds, lr:9.20e-04
# epoch:47/200 average TL:0.00067505 average VL:0.00061786 epoch time:1152 seconds, lr:9.40e-04
# epoch:48/200 average TL:0.00068950 average VL:0.00069402 epoch time:1172 seconds, lr:9.60e-04
# epoch:49/200 average TL:0.00067390 average VL:0.00065013 epoch time:1175 seconds, lr:9.80e-04
# epoch:50/200 average TL:0.00066815 average VL:0.00058562 epoch time:1173 seconds, lr:1.00e-03
# epoch:51/200 average TL:0.00065503 average VL:0.00062101 epoch time:1149 seconds, lr:1.00e-03
# epoch:52/200 average TL:0.00067257 average VL:0.00060331 epoch time:1155 seconds, lr:1.00e-03
# epoch:53/200 average TL:0.00065980 average VL:0.00065444 epoch time:1157 seconds, lr:9.99e-04
# epoch:54/200 average TL:0.00065406 average VL:0.00061688 epoch time:1149 seconds, lr:9.98e-04
# epoch:55/200 average TL:0.00065449 average VL:0.00049002 epoch time:1137 seconds, lr:9.97e-04
# epoch:56/200 average TL:0.00062619 average VL:0.00070926 epoch time:1140 seconds, lr:9.96e-04
# epoch:57/200 average TL:0.00063633 average VL:0.00050242 epoch time:1150 seconds, lr:9.95e-04
# epoch:58/200 average TL:0.00062862 average VL:0.00063253 epoch time:1136 seconds, lr:9.93e-04
# epoch:59/200 average TL:0.00061123 average VL:0.00061669 epoch time:1141 seconds, lr:9.91e-04
# epoch:60/200 average TL:0.00061870 average VL:0.00068202 epoch time:1136 seconds, lr:9.89e-04
# epoch:61/200 average TL:0.00061265 average VL:0.00058562 epoch time:1139 seconds, lr:9.87e-04
# epoch:62/200 average TL:0.00060889 average VL:0.00065630 epoch time:1156 seconds, lr:9.84e-04
# epoch:63/200 average TL:0.00061953 average VL:0.00055961 epoch time:1139 seconds, lr:9.82e-04
# epoch:64/200 average TL:0.00060005 average VL:0.00042158 epoch time:1142 seconds, lr:9.79e-04
# epoch:65/200 average TL:0.00059826 average VL:0.00065270 epoch time:1136 seconds, lr:9.76e-04
# epoch:66/200 average TL:0.00060327 average VL:0.00059640 epoch time:1137 seconds, lr:9.72e-04
# epoch:67/200 average TL:0.00059908 average VL:0.00060599 epoch time:1147 seconds, lr:9.69e-04
# epoch:68/200 average TL:0.00059787 average VL:0.00052304 epoch time:1140 seconds, lr:9.65e-04
# epoch:69/200 average TL:0.00059681 average VL:0.00053150 epoch time:1139 seconds, lr:9.61e-04
# epoch:70/200 average TL:0.00060207 average VL:0.00068668 epoch time:1142 seconds, lr:9.57e-04
# epoch:71/200 average TL:0.00057726 average VL:0.00063264 epoch time:1140 seconds, lr:9.52e-04
# epoch:72/200 average TL:0.00058637 average VL:0.00049732 epoch time:1145 seconds, lr:9.48e-04
# epoch:73/200 average TL:0.00056568 average VL:0.00059356 epoch time:1141 seconds, lr:9.43e-04
# epoch:74/200 average TL:0.00058030 average VL:0.00053905 epoch time:1139 seconds, lr:9.38e-04
# epoch:75/200 average TL:0.00058048 average VL:0.00057224 epoch time:1148 seconds, lr:9.33e-04
# epoch:76/200 average TL:0.00057563 average VL:0.00049965 epoch time:1138 seconds, lr:9.28e-04
# epoch:77/200 average TL:0.00056547 average VL:0.00057912 epoch time:1144 seconds, lr:9.22e-04
# epoch:78/200 average TL:0.00057580 average VL:0.00048830 epoch time:1138 seconds, lr:9.17e-04
# epoch:79/200 average TL:0.00054787 average VL:0.00057415 epoch time:1139 seconds, lr:9.11e-04
# epoch:80/200 average TL:0.00056336 average VL:0.00066022 epoch time:1135 seconds, lr:9.05e-04
# epoch:81/200 average TL:0.00055562 average VL:0.00043435 epoch time:1152 seconds, lr:8.98e-04
# epoch:82/200 average TL:0.00055310 average VL:0.00055192 epoch time:1145 seconds, lr:8.92e-04
# epoch:83/200 average TL:0.00055671 average VL:0.00043540 epoch time:1139 seconds, lr:8.85e-04
# epoch:84/200 average TL:0.00056545 average VL:0.00059618 epoch time:1140 seconds, lr:8.79e-04
# epoch:85/200 average TL:0.00054085 average VL:0.00053470 epoch time:1151 seconds, lr:8.72e-04
# epoch:86/200 average TL:0.00054910 average VL:0.00055867 epoch time:1140 seconds, lr:8.65e-04
# epoch:87/200 average TL:0.00055050 average VL:0.00055983 epoch time:1147 seconds, lr:8.57e-04
# epoch:88/200 average TL:0.00053928 average VL:0.00052871 epoch time:1137 seconds, lr:8.50e-04
# epoch:89/200 average TL:0.00053672 average VL:0.00049142 epoch time:1141 seconds, lr:8.42e-04
# epoch:90/200 average TL:0.00054575 average VL:0.00043557 epoch time:1140 seconds, lr:8.35e-04
# epoch:91/200 average TL:0.00053491 average VL:0.00046345 epoch time:1140 seconds, lr:8.27e-04
# epoch:92/200 average TL:0.00053253 average VL:0.00056348 epoch time:1140 seconds, lr:8.19e-04
# epoch:93/200 average TL:0.00052640 average VL:0.00053434 epoch time:1143 seconds, lr:8.11e-04
# epoch:94/200 average TL:0.00052819 average VL:0.00047175 epoch time:1139 seconds, lr:8.02e-04
# epoch:95/200 average TL:0.00053079 average VL:0.00048971 epoch time:1142 seconds, lr:7.94e-04
# epoch:96/200 average TL:0.00053709 average VL:0.00046669 epoch time:1137 seconds, lr:7.86e-04
# epoch:97/200 average TL:0.00052903 average VL:0.00064548 epoch time:1141 seconds, lr:7.77e-04
# epoch:98/200 average TL:0.00053168 average VL:0.00043041 epoch time:1137 seconds, lr:7.68e-04
# epoch:99/200 average TL:0.00052950 average VL:0.00060673 epoch time:1140 seconds, lr:7.59e-04
# epoch:100/200 average TL:0.00053480 average VL:0.00038624 epoch time:1139 seconds, lr:7.50e-04
# epoch:101/200 average TL:0.00051350 average VL:0.00048628 epoch time:1141 seconds, lr:7.41e-04
# epoch:102/200 average TL:0.00052315 average VL:0.00058604 epoch time:1139 seconds, lr:7.32e-04
# epoch:103/200 average TL:0.00050751 average VL:0.00041521 epoch time:1139 seconds, lr:7.23e-04
# epoch:104/200 average TL:0.00052115 average VL:0.00041659 epoch time:1142 seconds, lr:7.13e-04
# epoch:105/200 average TL:0.00051835 average VL:0.00048582 epoch time:1139 seconds, lr:7.04e-04
# epoch:106/200 average TL:0.00050291 average VL:0.00047144 epoch time:1144 seconds, lr:6.94e-04
# epoch:107/200 average TL:0.00050686 average VL:0.00046968 epoch time:1142 seconds, lr:6.84e-04
# epoch:108/200 average TL:0.00050707 average VL:0.00054065 epoch time:1137 seconds, lr:6.75e-04
# epoch:109/200 average TL:0.00050539 average VL:0.00041814 epoch time:1146 seconds, lr:6.65e-04
# epoch:110/200 average TL:0.00048728 average VL:0.00036060 epoch time:1139 seconds, lr:6.55e-04
# epoch:111/200 average TL:0.00050389 average VL:0.00054351 epoch time:1138 seconds, lr:6.45e-04
# epoch:112/200 average TL:0.00051406 average VL:0.00047450 epoch time:1141 seconds, lr:6.35e-04
# epoch:113/200 average TL:0.00050816 average VL:0.00045605 epoch time:1139 seconds, lr:6.25e-04
# epoch:114/200 average TL:0.00048618 average VL:0.00041106 epoch time:1142 seconds, lr:6.15e-04
# epoch:115/200 average TL:0.00049733 average VL:0.00054633 epoch time:1142 seconds, lr:6.04e-04
# epoch:116/200 average TL:0.00050851 average VL:0.00044585 epoch time:1138 seconds, lr:5.94e-04
# epoch:117/200 average TL:0.00050613 average VL:0.00042633 epoch time:1144 seconds, lr:5.84e-04
# epoch:118/200 average TL:0.00050200 average VL:0.00037723 epoch time:1140 seconds, lr:5.73e-04
# epoch:119/200 average TL:0.00049897 average VL:0.00046044 epoch time:1162 seconds, lr:5.63e-04
# epoch:120/200 average TL:0.00049479 average VL:0.00036732 epoch time:1148 seconds, lr:5.53e-04
# epoch:121/200 average TL:0.00048224 average VL:0.00055483 epoch time:1145 seconds, lr:5.42e-04
# epoch:122/200 average TL:0.00049224 average VL:0.00040315 epoch time:1143 seconds, lr:5.32e-04
# epoch:123/200 average TL:0.00049276 average VL:0.00042441 epoch time:1144 seconds, lr:5.21e-04
# epoch:124/200 average TL:0.00048512 average VL:0.00051314 epoch time:1136 seconds, lr:5.11e-04
# epoch:125/200 average TL:0.00047902 average VL:0.00035016 epoch time:1142 seconds, lr:5.01e-04
# epoch:126/200 average TL:0.00048896 average VL:0.00051212 epoch time:1139 seconds, lr:4.90e-04
# epoch:127/200 average TL:0.00048040 average VL:0.00049854 epoch time:1149 seconds, lr:4.80e-04
# epoch:128/200 average TL:0.00048803 average VL:0.00047555 epoch time:1139 seconds, lr:4.69e-04
# epoch:129/200 average TL:0.00048074 average VL:0.00042038 epoch time:1136 seconds, lr:4.59e-04
# epoch:130/200 average TL:0.00046971 average VL:0.00043449 epoch time:1143 seconds, lr:4.48e-04
# epoch:131/200 average TL:0.00048060 average VL:0.00041754 epoch time:1140 seconds, lr:4.38e-04
# epoch:132/200 average TL:0.00046665 average VL:0.00041464 epoch time:1142 seconds, lr:4.28e-04
# epoch:133/200 average TL:0.00047043 average VL:0.00040538 epoch time:1136 seconds, lr:4.17e-04
# epoch:134/200 average TL:0.00048235 average VL:0.00048751 epoch time:1136 seconds, lr:4.07e-04
# epoch:135/200 average TL:0.00047646 average VL:0.00035820 epoch time:1146 seconds, lr:3.97e-04
# epoch:136/200 average TL:0.00047371 average VL:0.00040726 epoch time:1147 seconds, lr:3.86e-04
# epoch:137/200 average TL:0.00047121 average VL:0.00046879 epoch time:1143 seconds, lr:3.76e-04
# epoch:138/200 average TL:0.00047575 average VL:0.00042728 epoch time:1142 seconds, lr:3.66e-04
# epoch:139/200 average TL:0.00048605 average VL:0.00039594 epoch time:1142 seconds, lr:3.56e-04
# epoch:140/200 average TL:0.00046962 average VL:0.00040263 epoch time:1135 seconds, lr:3.46e-04
# epoch:141/200 average TL:0.00047626 average VL:0.00043831 epoch time:1139 seconds, lr:3.36e-04
# epoch:142/200 average TL:0.00046274 average VL:0.00046829 epoch time:1147 seconds, lr:3.26e-04
# epoch:143/200 average TL:0.00046146 average VL:0.00042572 epoch time:1154 seconds, lr:3.17e-04
# epoch:144/200 average TL:0.00046462 average VL:0.00042992 epoch time:1137 seconds, lr:3.07e-04
# epoch:145/200 average TL:0.00047129 average VL:0.00035989 epoch time:1138 seconds, lr:2.97e-04
# epoch:146/200 average TL:0.00045230 average VL:0.00040090 epoch time:1141 seconds, lr:2.88e-04
# epoch:147/200 average TL:0.00046817 average VL:0.00042295 epoch time:1148 seconds, lr:2.78e-04
# epoch:148/200 average TL:0.00046893 average VL:0.00042176 epoch time:1142 seconds, lr:2.69e-04
# epoch:149/200 average TL:0.00046318 average VL:0.00040771 epoch time:1162 seconds, lr:2.60e-04
# epoch:150/200 average TL:0.00046454 average VL:0.00039278 epoch time:1151 seconds, lr:2.51e-04
# epoch:151/200 average TL:0.00045767 average VL:0.00041624 epoch time:1145 seconds, lr:2.42e-04
# epoch:152/200 average TL:0.00047294 average VL:0.00037143 epoch time:1137 seconds, lr:2.33e-04
# epoch:153/200 average TL:0.00044090 average VL:0.00036812 epoch time:1145 seconds, lr:2.24e-04
# epoch:154/200 average TL:0.00045470 average VL:0.00043358 epoch time:1142 seconds, lr:2.15e-04
# epoch:155/200 average TL:0.00045690 average VL:0.00036718 epoch time:1137 seconds, lr:2.07e-04
# epoch:156/200 average TL:0.00044435 average VL:0.00034116 epoch time:1154 seconds, lr:1.99e-04
# epoch:157/200 average TL:0.00045943 average VL:0.00042291 epoch time:1161 seconds, lr:1.90e-04
# epoch:158/200 average TL:0.00044497 average VL:0.00037837 epoch time:1140 seconds, lr:1.82e-04
# epoch:159/200 average TL:0.00044439 average VL:0.00036720 epoch time:1137 seconds, lr:1.74e-04
# epoch:160/200 average TL:0.00044636 average VL:0.00043170 epoch time:1139 seconds, lr:1.66e-04
# epoch:161/200 average TL:0.00045544 average VL:0.00032971 epoch time:1154 seconds, lr:1.59e-04
# epoch:162/200 average TL:0.00045037 average VL:0.00042467 epoch time:1146 seconds, lr:1.51e-04
# epoch:163/200 average TL:0.00044808 average VL:0.00045068 epoch time:1140 seconds, lr:1.44e-04
# epoch:164/200 average TL:0.00045562 average VL:0.00049822 epoch time:1143 seconds, lr:1.36e-04
# epoch:165/200 average TL:0.00044512 average VL:0.00041972 epoch time:1140 seconds, lr:1.29e-04
# epoch:166/200 average TL:0.00044252 average VL:0.00046517 epoch time:1143 seconds, lr:1.22e-04
# epoch:167/200 average TL:0.00043962 average VL:0.00040983 epoch time:1138 seconds, lr:1.16e-04
# epoch:168/200 average TL:0.00044384 average VL:0.00038336 epoch time:1136 seconds, lr:1.09e-04
# epoch:169/200 average TL:0.00045656 average VL:0.00046909 epoch time:1145 seconds, lr:1.03e-04
# epoch:170/200 average TL:0.00043863 average VL:0.00039964 epoch time:1141 seconds, lr:9.64e-05
# epoch:171/200 average TL:0.00044034 average VL:0.00042360 epoch time:1149 seconds, lr:9.03e-05
# epoch:172/200 average TL:0.00045177 average VL:0.00041735 epoch time:1139 seconds, lr:8.45e-05
# epoch:173/200 average TL:0.00044427 average VL:0.00038080 epoch time:1135 seconds, lr:7.88e-05
# epoch:174/200 average TL:0.00045144 average VL:0.00033315 epoch time:1154 seconds, lr:7.32e-05
# epoch:175/200 average TL:0.00043812 average VL:0.00052072 epoch time:1138 seconds, lr:6.79e-05
# epoch:176/200 average TL:0.00044145 average VL:0.00045676 epoch time:1144 seconds, lr:6.28e-05
# epoch:177/200 average TL:0.00045370 average VL:0.00041258 epoch time:1136 seconds, lr:5.78e-05
# epoch:178/200 average TL:0.00045015 average VL:0.00044795 epoch time:1140 seconds, lr:5.31e-05
# epoch:179/200 average TL:0.00045012 average VL:0.00041417 epoch time:1145 seconds, lr:4.85e-05
# epoch:180/200 average TL:0.00043990 average VL:0.00038738 epoch time:1139 seconds, lr:4.42e-05
# epoch:181/200 average TL:0.00043825 average VL:0.00041644 epoch time:1137 seconds, lr:4.00e-05
# epoch:182/200 average TL:0.00044393 average VL:0.00039498 epoch time:1137 seconds, lr:3.61e-05
# epoch:183/200 average TL:0.00043471 average VL:0.00049808 epoch time:1143 seconds, lr:3.23e-05
# epoch:184/200 average TL:0.00044734 average VL:0.00039463 epoch time:1146 seconds, lr:2.88e-05
# epoch:185/200 average TL:0.00043488 average VL:0.00044121 epoch time:1135 seconds, lr:2.54e-05
# epoch:186/200 average TL:0.00044804 average VL:0.00040737 epoch time:1140 seconds, lr:2.23e-05
# epoch:187/200 average TL:0.00043742 average VL:0.00034441 epoch time:1149 seconds, lr:1.94e-05
# epoch:188/200 average TL:0.00044127 average VL:0.00034927 epoch time:1143 seconds, lr:1.67e-05
# epoch:189/200 average TL:0.00044161 average VL:0.00035070 epoch time:1143 seconds, lr:1.42e-05
# epoch:190/200 average TL:0.00043653 average VL:0.00037685 epoch time:1149 seconds, lr:1.19e-05
# epoch:191/200 average TL:0.00043680 average VL:0.00051155 epoch time:1139 seconds, lr:9.85e-06
# epoch:192/200 average TL:0.00042622 average VL:0.00039691 epoch time:1143 seconds, lr:7.99e-06
# epoch:193/200 average TL:0.00043882 average VL:0.00041663 epoch time:1144 seconds, lr:6.36e-06
# epoch:194/200 average TL:0.00044264 average VL:0.00036275 epoch time:1136 seconds, lr:4.94e-06
# epoch:195/200 average TL:0.00043321 average VL:0.00036290 epoch time:1149 seconds, lr:3.74e-06
# epoch:196/200 average TL:0.00043091 average VL:0.00048311 epoch time:1140 seconds, lr:2.75e-06
# epoch:197/200 average TL:0.00043201 average VL:0.00047747 epoch time:1144 seconds, lr:1.99e-06
# epoch:198/200 average TL:0.00044221 average VL:0.00043681 epoch time:1148 seconds, lr:1.44e-06
# epoch:199/200 average TL:0.00043170 average VL:0.00042074 epoch time:1158 seconds, lr:1.11e-06
# epoch:200/200 average TL:0.00044568 average VL:0.00032323 epoch time:1142 seconds, lr:1.00e-06
#
# Duration: 229129 seconds

# %%
t1=iter(train_loader)
X,y=next(t1)
flops, params = thop.profile(ensemble, inputs=(X,), verbose=False)
print(f'Model Flops: {flops}')
print(f'Model Params Num: {params}\n')
# Out:
# Model Flops: 52639880000.0
# Model Params Num: 936850.0

# %%
dict={'train_losses':train_losses, 'val_losses':val_losses, 'flops':flops, 'parameters':params }
savemat(path_directory+'losses.mat', dict)
with open(path_directory+'losses.pkl', 'wb') as file:
    
    # A new file will be created
    pickle.dump(dict, file)

# %%
# Plotting
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
class LanguageDataset(Dataset):

    def __init__(self, dictionary, num_samples, num_errors):
        self.dictionary = dictionary
        self.num_samples = num_samples 
        self.num_errors = num_errors

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        source_idx = idx % len(self.dictionary)
        sequence = self.dictionary[source_idx]
        choice = torch.rand(1).item()
        if self.num_errors > 0:
            if choice >= 0 and choice< 0.10646:
                sequence = self.introduce_substitution_errors(sequence, self.num_errors)
                for _ in range(self.num_errors):
                    sequence.append('N')  
                sequence=''.join(sequence)
                #sequence= torch.cat([sequence, 'NNNN'], dim=1)
            elif choice >=0.10646 and choice < 0.14218:
                sequence = self.introduce_deletion_errors(sequence, self.num_errors)
                for _ in range(self.num_errors):
                    sequence.append('N') 
                sequence=''.join(sequence)
                #sequence= torch.cat([sequence, 'NNNN'], dim=1)
            elif choice >=0.14218 and choice < 0.15163:
                sequence = self.introduce_insertion_errors(sequence, self.num_errors)
                sequence=''.join(sequence)
            elif choice >=0.15163 and choice < 0.156:
                ne1 = self.num_errors//2
                ne2 = self.num_errors- ne1
                sequence = self.introduce_substitution_errors(sequence, ne1)
                sequence=''.join(sequence)
                sequence = self.introduce_deletion_errors(sequence, ne2)
                for _ in range(self.num_errors):
                    sequence.append('N') 
                sequence=''.join(sequence)
                #sequence= torch.cat([sequence, 'NNNN'], dim=1)
            elif choice >=0.156 and choice < 0.15701:
                ne1 = self.num_errors//2
                ne2 = self.num_errors- ne1
                sequence = self.introduce_substitution_errors(sequence, ne1)
                for _ in range(ne1):
                    sequence.append('N') 
                sequence=''.join(sequence)
                sequence = self.introduce_insertion_errors(sequence, ne2)
                sequence=''.join(sequence)
                
                
            elif choice >=0.15701 and choice < 0.1574:
                ne1 = self.num_errors//2
                ne2 = self.num_errors- ne1
                sequence = self.introduce_deletion_errors(sequence, ne1)
                for _ in range(ne1):
                    sequence.append('N') 
                sequence=''.join(sequence)
                sequence = self.introduce_insertion_errors(sequence, ne2)
                sequence=''.join(sequence)
                
            elif choice >=0.1574 and choice < 0.15747:
                ne1 = self.num_errors//3
                ne2 = self.num_errors//3
                ne3 = self.num_errors- ne1-ne2
                sequence = self.introduce_substitution_errors(sequence, ne1)
                for _ in range(ne1):
                    sequence.append('N')
                sequence=''.join(sequence)
                sequence = self.introduce_deletion_errors(sequence, ne2)
                for _ in range(ne2):
                    sequence.append('N')
                sequence=''.join(sequence)
                sequence = self.introduce_insertion_errors(sequence, ne3)
                sequence=''.join(sequence)
                 
            else:
                sequence = list(sequence)
                for _ in range(self.num_errors):
                    sequence.append('N') 
                sequence=''.join(sequence)   
            
        x = torch.tensor([self.char_to_idx(c) for c in sequence], dtype=torch.long)
        y = torch.tensor([self.char_to_idx(c) for c in self.dictionary[source_idx]], dtype=torch.long)
        return x.to(device), y.to(device)

    def introduce_deletion_errors(self, sequence, num_errors):
        #ne = random.randint(1, num_errors)
        sequence = list(sequence)
        
        for _ in range(num_errors):
            i = random.randint(0, len(sequence)-1)
            del sequence[i]
            sequence.append('N') 
        
        return sequence
    
    def introduce_substitution_errors(self, sequence, num_errors):
        #ne = random.randint(1, num_errors)
        sequence = list(sequence)
        for _ in range(num_errors):
            i = random.randint(0, len(sequence)-1)
            if sequence[i] == 'A':
                sequence[i] = random.choice(['T', 'G', 'C'])
            elif sequence[i] == 'T':
                sequence[i] = random.choice(['A', 'G', 'C'])
            elif sequence[i] == 'G':
                sequence[i] = random.choice(['A', 'T', 'C'])
            elif sequence[i] == 'C':
                sequence[i] = random.choice(['A', 'T', 'G'])
        
        return sequence
    
    def introduce_insertion_errors(self, sequence, num_errors):
        #ne = random.randint(1, num_errors)
        sequence = list(sequence)
        #for _ in range(num_errors-ne):
        #    sequence.append('N')
        for _ in range(num_errors):
            i = random.randint(0, len(sequence))
            random_char = random.choice(['A','C','T','G']) 
            sequence.insert(i, random_char)
        return sequence

    def char_to_idx(self, char):
        return {'A': 0, 'C': 1, 'T': 2, 'G': 3, 'N': 4}[char]

# %%
start_test=1
stop_test=4
num_test=200000
test_error_points=torch.arange(start_test, stop_test+1)
#nucleotide error rate
ner=torch.zeros((stop_test-start_test+1)).to(device)
#sequence error rate
ser=torch.zeros((stop_test-start_test+1)).to(device)
time_tensor =torch.zeros((stop_test-start_test+1)).to(device)

# %%
def count_different_rows(matrix1, matrix2):
    """
    Calculates the number of rows that are not equal between two 2D PyTorch matrices.

    Args:
        matrix1 (torch.Tensor): A 2D PyTorch tensor of shape (m, n).
        matrix2 (torch.Tensor): A 2D PyTorch tensor of shape (m, n).

    Returns:
        int: The number of rows that are not equal between the two matrices.
    """
    assert matrix1.shape == matrix2.shape, "The input matrices must have the same shape."
    equal_rows = torch.all(matrix1 == matrix2, dim=1)
    return matrix1.shape[0] - torch.sum(equal_rows).item()

# %%
i1=0
for i in range(start_test, stop_test+1):
    test_data1 = LanguageDataset(dicts, num_samples=num_test, num_errors=i)
    test_loader1 = DataLoader(test_data1, batch_size=batch_size, shuffle=True)
    n_tbatch=len(test_loader1)
    ne=0.0
    count=0.0
    decoding_time =0
    # Run the testing batches
    ensemble.eval()
    with torch.no_grad():
        for b, (X_test, y_test) in enumerate(test_loader1):
            # Apply the model
            start_time = time.time()
            y_pred=ensemble(X_test)
            decoding_time = decoding_time + time.time()-start_time
            y_pred_d=one_hot_decode(y_pred)
            
            y_pred_dk = y_pred_d[:,:K]
            ne=ne+torch.sum(y_pred_dk!=y_test).item()
            count=count+count_different_rows(y_test,y_pred_dk)
        time_tensor[i1] = decoding_time/(n_tbatch*batch_size)
        ner[i1]=ne/(n_tbatch*batch_size*K)
        ser[i1]=count/(n_tbatch*batch_size)
    i1=i1+1

# %%
time_tensor
# Out:
# tensor([0.0010, 0.0010, 0.0011, 0.0011], device='cuda:0')

# %%
ner
# Out:
# tensor([0.0021, 0.0039, 0.0044, 0.0111], device='cuda:0')

# %%
plt.plot(torch.Tensor.cpu(test_error_points).numpy(),torch.Tensor.cpu(ner).numpy())
plt.yscale('log')
plt.xlabel('Number of errors')
plt.ylabel('NER')    
plt.grid(True)
plt.show()

# %%
dict1={'ner':torch.Tensor.cpu(ner).numpy(), 'ser':torch.Tensor.cpu(ser).numpy()}
savemat(path_directory+'metric.mat', dict1)
with open(path_directory+'metric.pkl', 'wb') as file:
    
    # A new file will be created
    pickle.dump(dict1, file)
